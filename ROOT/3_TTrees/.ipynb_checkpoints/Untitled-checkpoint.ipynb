# %%
# %matplotlib inline
import os, sys, json
import numpy as np
import pandas as pd
import root_numpy as rnp
import matplotlib.pyplot as plt
from collections import OrderedDict as OD
from ipywidgets import interact, interactive, fixed, widgets
from NotebookUtils.ProgressBar import LogProgress as LP
plt.rcParams['font.family']='serif'
plt.rcParams['font.weight']='light'
plt.rcParams['font.size']=14
figsize = (12,6)

# %%
def Pandafy(fileName, tree):
    df = pd.DataFrame(rnp.root2array(fileName,tree))
    return df

inDir = './'
fileNames = [inDir+fileName for fileName in os.listdir(inDir) if '.root' in fileName]
df_v = [Pandafy(fileName,'Tree') for fileName in fileNames]
df = pd.concat(df_v,ignore_index=True)
df
# Out:
#    TrackLength  NumHits_nHits_U  NumHits_nHits_V  NumHits_nHits_Y  \
# 0         31.0                3                3                3
# 1         89.0                3                3                3
# 2         15.0                3                3                3
# 3          9.0                3                3                3
# 4         54.0                3                3                3
# 5         95.0                3                3                3
# 6          6.0                3                3                3
# 7          9.0                3                3                3
# 8         91.0                3                3                3
# 9         27.0                3                3                3
#
#    Hit_PulseHeight_U  Hit_PulseHeight_V  Hit_PulseHeight_Y
# 0      -3.387561e-08                0.0                0.0
# 1      -3.387561e-08                0.0                0.0
# 2      -3.387561e-08                0.0                0.0
# 3      -3.387561e-08                0.0                0.0
# 4      -3.387561e-08                0.0                0.0
# 5      -3.387561e-08                0.0                0.0
# 6      -3.387561e-08                0.0                0.0
# 7      -3.387561e-08                0.0                0.0
# 8      -3.387561e-08                0.0                0.0
# 9      -3.387561e-08                0.0                0.0
