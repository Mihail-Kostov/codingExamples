# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.family']='serif'
plt.rcParams['font.weight']='light'
plt.rcParams['font.size']=14
figsize = (12,8)

fig = plt.figure(figsize=figsize)
plt.bar(xInd,nHist,yerr=nErr)
plt.xticks(xInd, xLabels)

ax = plt.gca()
rects = ax.patches
labels = ["%.2g" %(val) for val in nHist]
for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height+0.01, label, ha='center', va='bottom')
plt.title("Swtrigger Pass fraction with 142k\nprodgenie_bnb_intrinsic_nue_cosmic_uboone_mcc8.4_reco2 events")
    
plt.show()

# %%
data  = [340,531,18,236,98]
xLabel = ['Data1','Data2','Data3','Data4','Data5']
norm = n


fig = plt.figure(figsize=figsize)
HepHist(sigDistance,nbins,xlims,xtrim=True,norm=True,color='C0',label=r'$N \rightarrow e \pi$',fill=True)
HepHist(bkgDistance,nbins,xlims,xtrim=True,norm=True,color='C3',label='BNB',fill=True)
plt.title('Track-Shower distances')
plt.xlabel('Distance [cm]')
plt.legend()
plt.draw()
